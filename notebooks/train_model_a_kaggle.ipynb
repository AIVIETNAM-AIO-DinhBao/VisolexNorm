# %% [markdown]
# # Phase 2 — Train Model A (ViLexNorm gold-only)
# Attach a Kaggle Dataset containing the repository code and another private Dataset containing `vilexnorm_train.jsonl` and `vilexnorm_dev.jsonl`. Enable GPU and Internet for the first BARTpho download. This notebook does not load the Test split.

# %%
# !pip install -q -r /kaggle/input/visolexnorm-code/requirements-kaggle.txt
import os, shutil, torch, transformers
print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'No GPU')
print('torch:', torch.__version__, '| transformers:', transformers.__version__)

# %%
# Change only these two paths if your Kaggle Dataset slugs differ.
CODE_DIR = '/kaggle/input/visolexnorm-code'
DATA_DIR = '/kaggle/input/visolexnorm-processed'
WORK_DIR = '/kaggle/working'
# !python {CODE_DIR}/scripts/train_model_a.py --data-dir {DATA_DIR} --config {CODE_DIR}/configs/model_a_config.json --work-dir {WORK_DIR}

# %%
# Inspect and save Kaggle output/version after this cell succeeds.
# !cat /kaggle/working/outputs/model_a/dev_metrics.json
# !cd /kaggle/working && zip -r model_a_artifacts.zip checkpoints/model_a outputs/model_a
